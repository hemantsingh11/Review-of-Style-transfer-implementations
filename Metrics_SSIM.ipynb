# %% [markdown]
# # Import Libraries

# %%
import os 
import numpy as np 
from skimage.metrics import structural_similarity as ssim
import cv2
import subprocess

# %% [markdown]
# # Get Image Tuples

# %%
def get_image_tuples(cd, sd, od ):

  content_dir = cd
  style_dir = sd
  out_dir = od

  # to get image tuples of only one style
  only_one_style_all_images = False
  style_image_name = ["1.jpg"]

  image_tuples = []

  if only_one_style_all_images:
    for s in style_image_name:
      if ".DS_Store" in s:
        continue
      sn = s.split(".")[0]
      for c in os.listdir(content_dir):
        if ".DS_Store" in c:
          continue
        cn = c.split(".")[0]
        fsp = os.path.join(style_dir,s)
        fcp = os.path.join(content_dir,c)
        
        on = "content_"+str(cn)+"_style_"+str(sn)+".jpg"
        op = os.path.join(out_dir,on)
        image_tuples.append((fcp,fsp,op))

  else:  
    for c in sorted(os.listdir(content_dir)):
      if ".DS_Store" in c:
        continue
      for s in sorted(os.listdir(style_dir)):
        if ".DS_Store" in c:
          continue
        sn = s.split(".")[0]
        cn = c.split(".")[0]
        fsp = os.path.join(style_dir,s)
        fcp = os.path.join(content_dir,c)
        
        on = "content_"+str(cn)+"_style_"+str(sn)+".jpg"
        op = os.path.join(out_dir,on)
        image_tuples.append((fcp,fsp,op))

      # also make output directory if missing 
      # subprocess.run("mkdir "+str(out_dir), shell = True)

  return image_tuples

# %%
# sorted(os.listdir("/content/image_files_metrics/content"))
# Out:
# ['building.jpg', 'car.jpg', 'dog.jpg', 'painting.jpg', 'person.jpg']

# %% [markdown]
# # Get your files Unzipped

# %%
# !unzip /content/image_files_metrics.zip
# Out:
# Archive:  /content/image_files_metrics.zip
#    creating: image_files_metrics/
#   inflating: __MACOSX/._image_files_metrics
#   inflating: image_files_metrics/.DS_Store
#   inflating: __MACOSX/image_files_metrics/._.DS_Store
#    creating: image_files_metrics/fast_style_256/
#   inflating: __MACOSX/image_files_metrics/._fast_style_256
#    creating: image_files_metrics/content/
#    creating: image_files_metrics/style/
#    creating: image_files_metrics/artistic_256/
#   inflating: __MACOSX/image_files_metrics/._artistic_256
#    creating: image_files_metrics/dfr_256/
#   inflating: __MACOSX/image_files_metrics/._dfr_256
#    creating: image_files_metrics/nst_256/
#   inflating: __MACOSX/image_files_metrics/._nst_256
#   inflating: image_files_metrics/fast_style_256/content_car_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_car_style_1.jpg
#   inflating: image_files_metrics/fast_style_256/content_building_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_building_style_3.jpg
#   inflating: image_files_metrics/fast_style_256/content_building_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_building_style_2.jpg
#   inflating: image_files_metrics/fast_style_256/content_car_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_car_style_2.jpg
#   inflating: image_files_metrics/fast_style_256/content_building_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_building_style_1.jpg
#   inflating: image_files_metrics/fast_style_256/content_car_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_car_style_3.jpg
#   inflating: image_files_metrics/fast_style_256/content_building_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_building_style_5.jpg
#   inflating: image_files_metrics/fast_style_256/content_building_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_building_style_4.jpg
#   inflating: image_files_metrics/fast_style_256/content_car_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_car_style_4.jpg
#   inflating: image_files_metrics/fast_style_256/content_car_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_car_style_5.jpg
#   inflating: image_files_metrics/fast_style_256/content_person_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_person_style_3.jpg
#   inflating: image_files_metrics/fast_style_256/content_person_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_person_style_2.jpg
#   inflating: image_files_metrics/fast_style_256/content_person_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_person_style_1.jpg
#   inflating: image_files_metrics/fast_style_256/content_person_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_person_style_5.jpg
#   inflating: image_files_metrics/fast_style_256/content_person_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_person_style_4.jpg
#   inflating: image_files_metrics/fast_style_256/content_painting_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_painting_style_5.jpg
#   inflating: image_files_metrics/fast_style_256/content_painting_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_painting_style_4.jpg
#   inflating: image_files_metrics/fast_style_256/content_painting_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_painting_style_1.jpg
#   inflating: image_files_metrics/fast_style_256/content_painting_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_painting_style_3.jpg
#   inflating: image_files_metrics/fast_style_256/content_painting_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_painting_style_2.jpg
#   inflating: image_files_metrics/fast_style_256/content_dog_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_dog_style_5.jpg
#   inflating: image_files_metrics/fast_style_256/content_dog_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_dog_style_4.jpg
#   inflating: image_files_metrics/fast_style_256/content_dog_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_dog_style_1.jpg
#   inflating: image_files_metrics/fast_style_256/content_dog_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_dog_style_3.jpg
#   inflating: image_files_metrics/fast_style_256/content_dog_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_dog_style_2.jpg
#   inflating: image_files_metrics/content/dog.jpg
#   inflating: __MACOSX/image_files_metrics/content/._dog.jpg
#   inflating: image_files_metrics/content/person.jpg
#   inflating: __MACOSX/image_files_metrics/content/._person.jpg
#   inflating: image_files_metrics/content/painting.jpg
#   inflating: __MACOSX/image_files_metrics/content/._painting.jpg
#   inflating: image_files_metrics/content/building.jpg
#   inflating: __MACOSX/image_files_metrics/content/._building.jpg
#   inflating: image_files_metrics/content/car.jpg
#   inflating: __MACOSX/image_files_metrics/content/._car.jpg
#   inflating: image_files_metrics/style/4.jpg
#   inflating: __MACOSX/image_files_metrics/style/._4.jpg
#   inflating: image_files_metrics/style/5.jpg
#   inflating: __MACOSX/image_files_metrics/style/._5.jpg
#   inflating: image_files_metrics/style/2.jpg
#   inflating: __MACOSX/image_files_metrics/style/._2.jpg
#   inflating: image_files_metrics/style/3.jpg
#   inflating: __MACOSX/image_files_metrics/style/._3.jpg
#   inflating: image_files_metrics/style/1.jpg
#   inflating: __MACOSX/image_files_metrics/style/._1.jpg
#   inflating: image_files_metrics/artistic_256/content_car_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_car_style_1.jpg
#   inflating: image_files_metrics/artistic_256/content_building_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_building_style_3.jpg
#   inflating: image_files_metrics/artistic_256/content_building_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_building_style_2.jpg
#   inflating: image_files_metrics/artistic_256/content_car_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_car_style_2.jpg
#   inflating: image_files_metrics/artistic_256/content_building_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_building_style_1.jpg
#   inflating: image_files_metrics/artistic_256/content_car_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_car_style_3.jpg
#   inflating: image_files_metrics/artistic_256/content_building_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_building_style_5.jpg
#   inflating: image_files_metrics/artistic_256/content_building_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_building_style_4.jpg
#   inflating: image_files_metrics/artistic_256/content_car_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_car_style_4.jpg
#   inflating: image_files_metrics/artistic_256/content_car_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_car_style_5.jpg
#   inflating: image_files_metrics/artistic_256/content_person_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_person_style_3.jpg
#   inflating: image_files_metrics/artistic_256/content_person_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_person_style_2.jpg
#   inflating: image_files_metrics/artistic_256/content_person_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_person_style_1.jpg
#   inflating: image_files_metrics/artistic_256/content_person_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_person_style_5.jpg
#   inflating: image_files_metrics/artistic_256/content_person_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_person_style_4.jpg
#   inflating: image_files_metrics/artistic_256/content_painting_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_painting_style_5.jpg
#   inflating: image_files_metrics/artistic_256/content_painting_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_painting_style_4.jpg
#   inflating: image_files_metrics/artistic_256/content_painting_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_painting_style_1.jpg
#   inflating: image_files_metrics/artistic_256/content_painting_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_painting_style_3.jpg
#   inflating: image_files_metrics/artistic_256/content_painting_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_painting_style_2.jpg
#   inflating: image_files_metrics/artistic_256/content_dog_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_dog_style_5.jpg
#   inflating: image_files_metrics/artistic_256/content_dog_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_dog_style_4.jpg
#   inflating: image_files_metrics/artistic_256/content_dog_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_dog_style_1.jpg
#   inflating: image_files_metrics/artistic_256/content_dog_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_dog_style_3.jpg
#   inflating: image_files_metrics/artistic_256/content_dog_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_256/._content_dog_style_2.jpg
#   inflating: image_files_metrics/dfr_256/content_car_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_car_style_1.jpg
#   inflating: image_files_metrics/dfr_256/content_building_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_building_style_3.jpg
#   inflating: image_files_metrics/dfr_256/content_building_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_building_style_2.jpg
#   inflating: image_files_metrics/dfr_256/content_car_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_car_style_2.jpg
#   inflating: image_files_metrics/dfr_256/content_building_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_building_style_1.jpg
#   inflating: image_files_metrics/dfr_256/content_car_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_car_style_3.jpg
#   inflating: image_files_metrics/dfr_256/content_building_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_building_style_5.jpg
#   inflating: image_files_metrics/dfr_256/content_building_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_building_style_4.jpg
#   inflating: image_files_metrics/dfr_256/content_car_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_car_style_4.jpg
#   inflating: image_files_metrics/dfr_256/content_car_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_car_style_5.jpg
#   inflating: image_files_metrics/dfr_256/content_person_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_person_style_3.jpg
#   inflating: image_files_metrics/dfr_256/content_person_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_person_style_2.jpg
#   inflating: image_files_metrics/dfr_256/content_person_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_person_style_1.jpg
#   inflating: image_files_metrics/dfr_256/content_person_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_person_style_5.jpg
#   inflating: image_files_metrics/dfr_256/content_person_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_person_style_4.jpg
#   inflating: image_files_metrics/dfr_256/content_painting_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_painting_style_5.jpg
#   inflating: image_files_metrics/dfr_256/content_painting_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_painting_style_4.jpg
#   inflating: image_files_metrics/dfr_256/content_painting_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_painting_style_1.jpg
#   inflating: image_files_metrics/dfr_256/content_painting_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_painting_style_3.jpg
#   inflating: image_files_metrics/dfr_256/content_painting_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_painting_style_2.jpg
#   inflating: image_files_metrics/dfr_256/content_dog_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_dog_style_5.jpg
#   inflating: image_files_metrics/dfr_256/content_dog_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_dog_style_4.jpg
#   inflating: image_files_metrics/dfr_256/content_dog_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_dog_style_1.jpg
#   inflating: image_files_metrics/dfr_256/content_dog_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_dog_style_3.jpg
#   inflating: image_files_metrics/dfr_256/content_dog_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/dfr_256/._content_dog_style_2.jpg
#   inflating: image_files_metrics/nst_256/content_car_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_car_style_1.jpg
#   inflating: image_files_metrics/nst_256/content_building_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_building_style_3.jpg
#   inflating: image_files_metrics/nst_256/content_building_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_building_style_2.jpg
#   inflating: image_files_metrics/nst_256/content_car_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_car_style_2.jpg
#   inflating: image_files_metrics/nst_256/content_building_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_building_style_1.jpg
#   inflating: image_files_metrics/nst_256/content_car_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_car_style_3.jpg
#   inflating: image_files_metrics/nst_256/content_building_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_building_style_5.jpg
#   inflating: image_files_metrics/nst_256/content_building_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_building_style_4.jpg
#   inflating: image_files_metrics/nst_256/content_car_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_car_style_4.jpg
#   inflating: image_files_metrics/nst_256/content_car_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_car_style_5.jpg
#   inflating: image_files_metrics/nst_256/content_person_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_person_style_3.jpg
#   inflating: image_files_metrics/nst_256/content_person_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_person_style_2.jpg
#   inflating: image_files_metrics/nst_256/content_person_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_person_style_1.jpg
#   inflating: image_files_metrics/nst_256/content_person_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_person_style_5.jpg
#   inflating: image_files_metrics/nst_256/content_person_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_person_style_4.jpg
#   inflating: image_files_metrics/nst_256/content_painting_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_painting_style_5.jpg
#   inflating: image_files_metrics/nst_256/content_painting_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_painting_style_4.jpg
#   inflating: image_files_metrics/nst_256/content_painting_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_painting_style_1.jpg
#   inflating: image_files_metrics/nst_256/content_painting_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_painting_style_3.jpg
#   inflating: image_files_metrics/nst_256/content_painting_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_painting_style_2.jpg
#   inflating: image_files_metrics/nst_256/content_dog_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_dog_style_5.jpg
#   inflating: image_files_metrics/nst_256/content_dog_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_dog_style_4.jpg
#   inflating: image_files_metrics/nst_256/content_dog_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_dog_style_1.jpg
#   inflating: image_files_metrics/nst_256/content_dog_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_dog_style_3.jpg
#   inflating: image_files_metrics/nst_256/content_dog_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/nst_256/._content_dog_style_2.jpg

# %% [markdown]
# # Fast Style

# %%
def ssim_score(imgp1, imgp2):
  img1 = cv2.imread(imgp1)
  img2 = cv2.imread(imgp2)
  gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
  gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

  # calculate the SSIM score
  score = ssim(gray1, gray2)
  return score

cd = "/content/image_files_metrics/content" # @param {type:"string"}
sd = "/content/image_files_metrics/style"# @param {type:"string"}
od = "/content/image_files_metrics/fast_style_256"# @param {type:"string"}
image_tuples = get_image_tuples(cd = cd , sd = sd , od = od )
print(image_tuples)

print("Total Inferences: {}".format(len(image_tuples)))
count = 0
ssim_score_array_oc = []
ssim_score_array_os = []
for t in image_tuples:
  cp, sp, op = t[0],t[1],t[2]
  # print(cp)
  # print(sp)
  # print(op)
  count += 1
  score_oc = ssim_score(op, cp)
  score_os = ssim_score(op, sp)
  # print("Processing Inference :{}/{} Image : {} , score : {}".format(count, len(image_tuples), op , score))
  ssim_score_array_oc.append(score_oc)
  ssim_score_array_os.append(score_os)

print("output_content_ssim: {}".format(ssim_score_array_oc))
print("avg output_content_ssim score: {}".format(np.mean(np.array(ssim_score_array_oc))) )
print("output_style_ssim: {}".format(ssim_score_array_os))
print("avg output_style_ssim score: {}".format(np.mean(np.array(ssim_score_array_os))) )
# Out:
# [('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/fast_style_256/content_building_style_1.jpg'), ('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/fast_style_256/content_building_style_2.jpg'), ('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/fast_style_256/content_building_style_3.jpg'), ('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/fast_style_256/content_building_style_4.jpg'), ('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/5.jpg', '/content/image_files_metrics/fast_style_256/content_building_style_5.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/fast_style_256/content_car_style_1.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/fast_style_256/content_car_style_2.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/fast_style_256/content_car_style_3.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/fast_style_256/content_car_style_4.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/5.jpg', '/content/image_files_metrics/fast_style_256/content_car_style_5.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/fast_style_256/content_dog_style_1.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/fast_style_256/content_dog_style_2.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/fast_style_256/content_dog_style_3.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/fast_style_256/content_dog_style_4.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/5.jpg', '/content/image_files_metrics/fast_style_256/content_dog_style_5.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/fast_style_256/content_painting_style_1.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/fast_style_256/content_painting_style_2.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/fast_style_256/content_painting_style_3.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/fast_style_256/content_painting_style_4.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/5.jpg', '/content/image_files_metrics/fast_style_256/content_painting_style_5.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/fast_style_256/content_person_style_1.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/fast_style_256/content_person_style_2.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/fast_style_256/content_person_style_3.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/styl ...
# Total Inferences: 25
# output_content_ssim: [0.41826128411145413, 0.559311351507912, 0.4677214925046697, 0.15856935141747333, 0.48168520762593786, 0.33868890088106257, 0.4785866666015451, 0.5401453801110007, 0.2913674239077182, 0.3072646005401312, 0.4671822533451772, 0.6683812115713347, 0.7376074520951543, 0.3400800697259076, 0.42511197301227316, 0.40415697379654203, 0.4512944233334624, 0.5224600303991023, 0.30438855181166613, 0.33647175824000347, 0.48703860455526243, 0.510123556670477, 0.4307791047487009, 0.1828242155795048, 0.45978444599902024]
# avg output_content_ssim score: 0.4307714513636997
# output_style_ssim: [0.06265444127479322, 0.15772711700949066, 0.26423977363539325, 0.25524697184395057, 0.05572136395268884, 0.07971296440756725, 0.1574887799476444, 0.27080494711261427, 0.28017754890368674, 0.0444179621553041, 0.05941478049194774, 0.16132454411982808, 0.28356341431183524, 0.29961173055925855, 0.048745082123930944, 0.06615885287379832, 0.15338004336069908, 0.26315046705250345, 0.28955226201954454, 0.04656912126225335, 0.08352301451692361, 0.14606632113163562, 0.252688604480374, 0.2936601900235977, 0.04509232006297216]
# avg output_style_ssim score: 0.16482770474536942

# %% [markdown]
# # Artistic

# %%
def ssim_score(imgp1, imgp2):
  img1 = cv2.imread(imgp1)
  img2 = cv2.imread(imgp2)
  gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
  gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

  # calculate the SSIM score
  score = ssim(gray1, gray2)
  return score

cd = "/content/image_files_metrics/content" # @param {type:"string"}
sd = "/content/image_files_metrics/style"# @param {type:"string"}
od = "/content/image_files_metrics/artistic_256"# @param {type:"string"}
image_tuples = get_image_tuples(cd = cd , sd = sd , od = od )
print(image_tuples)

print("Total Inferences: {}".format(len(image_tuples)))
count = 0
ssim_score_array_oc = []
ssim_score_array_os = []
for t in image_tuples:
  cp, sp, op = t[0],t[1],t[2]
  # print(cp)
  # print(sp)
  # print(op)
  count += 1
  score_oc = ssim_score(op, cp)
  score_os = ssim_score(op, sp)
  # print("Processing Inference :{}/{} Image : {} , score : {}".format(count, len(image_tuples), op , score))
  ssim_score_array_oc.append(score_oc)
  ssim_score_array_os.append(score_os)

print("output_content_ssim: {}".format(ssim_score_array_oc))
print("avg output_content_ssim score: {}".format(np.mean(np.array(ssim_score_array_oc))) )
print("output_style_ssim: {}".format(ssim_score_array_os))
print("avg output_style_ssim score: {}".format(np.mean(np.array(ssim_score_array_os))) )
# Out:
# [('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/artistic_256/content_building_style_1.jpg'), ('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/artistic_256/content_building_style_2.jpg'), ('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/artistic_256/content_building_style_3.jpg'), ('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/artistic_256/content_building_style_4.jpg'), ('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/5.jpg', '/content/image_files_metrics/artistic_256/content_building_style_5.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/artistic_256/content_car_style_1.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/artistic_256/content_car_style_2.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/artistic_256/content_car_style_3.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/artistic_256/content_car_style_4.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/5.jpg', '/content/image_files_metrics/artistic_256/content_car_style_5.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/artistic_256/content_dog_style_1.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/artistic_256/content_dog_style_2.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/artistic_256/content_dog_style_3.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/artistic_256/content_dog_style_4.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/5.jpg', '/content/image_files_metrics/artistic_256/content_dog_style_5.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/artistic_256/content_painting_style_1.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/artistic_256/content_painting_style_2.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/artistic_256/content_painting_style_3.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/artistic_256/content_painting_style_4.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/5.jpg', '/content/image_files_metrics/artistic_256/content_painting_style_5.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/artistic_256/content_person_style_1.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/artistic_256/content_person_style_2.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/artistic_256/content_person_style_3.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/artist ...
# Total Inferences: 25
# output_content_ssim: [0.6833245807433542, 0.7042273324619602, 0.7469640326268505, 0.6650714057725856, 0.637346919962599, 0.5113679663567691, 0.5830642347723566, 0.7286773138674473, 0.6557425117641068, 0.49415617974017845, 0.5866276730130228, 0.6988480490778742, 0.7912316315552723, 0.6572581128183269, 0.5677730125349076, 0.4941649070226188, 0.5524206534473384, 0.6904624216585032, 0.6339546561231403, 0.489117332223481, 0.681791138113586, 0.6913796262566965, 0.7249469141140831, 0.6659563317452611, 0.6282688582201075]
# avg output_content_ssim score: 0.6385657518396971
# output_style_ssim: [0.05230499271556848, 0.09024631052929209, 0.14234437380880288, 0.1570018300744917, 0.047113266412706446, 0.06408311708118246, 0.1025724045893211, 0.208083577974454, 0.18831549449514914, 0.04727870039059421, 0.06375310069692079, 0.14263454702804962, 0.22930239522232615, 0.20197521868420557, 0.04148006505732035, 0.0584141607794568, 0.09489402849928785, 0.20282211302634115, 0.17490032400333624, 0.04183371017922138, 0.06725089281055951, 0.09644797051170115, 0.1493686526057533, 0.17513812740589826, 0.04135913661043912]
# avg output_style_ssim score: 0.11523674044769519

# %% [markdown]
# # DFR

# %%
def ssim_score(imgp1, imgp2):
  img1 = cv2.imread(imgp1)
  img2 = cv2.imread(imgp2)
  gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
  gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

  # calculate the SSIM score
  score = ssim(gray1, gray2)
  return score

cd = "/content/image_files_metrics/content" # @param {type:"string"}
sd = "/content/image_files_metrics/style"# @param {type:"string"}
od = "/content/image_files_metrics/dfr_256"# @param {type:"string"}
image_tuples = get_image_tuples(cd = cd , sd = sd , od = od )
print(image_tuples)

print("Total Inferences: {}".format(len(image_tuples)))
count = 0
ssim_score_array_oc = []
ssim_score_array_os = []
for t in image_tuples:
  cp, sp, op = t[0],t[1],t[2]
  # print(cp)
  # print(sp)
  # print(op)
  count += 1
  score_oc = ssim_score(op, cp)
  score_os = ssim_score(op, sp)
  # print("Processing Inference :{}/{} Image : {} , score : {}".format(count, len(image_tuples), op , score))
  ssim_score_array_oc.append(score_oc)
  ssim_score_array_os.append(score_os)

print("output_content_ssim: {}".format(ssim_score_array_oc))
print("avg output_content_ssim score: {}".format(np.mean(np.array(ssim_score_array_oc))) )
print("output_style_ssim: {}".format(ssim_score_array_os))
print("avg output_style_ssim score: {}".format(np.mean(np.array(ssim_score_array_os))) )
# Out:
# [('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/dfr_256/content_building_style_1.jpg'), ('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/dfr_256/content_building_style_2.jpg'), ('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/dfr_256/content_building_style_3.jpg'), ('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/dfr_256/content_building_style_4.jpg'), ('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/5.jpg', '/content/image_files_metrics/dfr_256/content_building_style_5.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/dfr_256/content_car_style_1.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/dfr_256/content_car_style_2.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/dfr_256/content_car_style_3.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/dfr_256/content_car_style_4.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/5.jpg', '/content/image_files_metrics/dfr_256/content_car_style_5.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/dfr_256/content_dog_style_1.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/dfr_256/content_dog_style_2.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/dfr_256/content_dog_style_3.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/dfr_256/content_dog_style_4.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/5.jpg', '/content/image_files_metrics/dfr_256/content_dog_style_5.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/dfr_256/content_painting_style_1.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/dfr_256/content_painting_style_2.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/dfr_256/content_painting_style_3.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/dfr_256/content_painting_style_4.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/5.jpg', '/content/image_files_metrics/dfr_256/content_painting_style_5.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/dfr_256/content_person_style_1.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/dfr_256/content_person_style_2.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/dfr_256/content_person_style_3.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/dfr_256/content_person_style_4.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/s ...
# Total Inferences: 25
# output_content_ssim: [0.25633175279576476, 0.24641512234651755, 0.26324073079164334, 0.2765125775533512, 0.2856163468972714, 0.18501082890187573, 0.18297896720976967, 0.2955950329029968, 0.21016431990770992, 0.1590175229950247, 0.2020233111285856, 0.23691130319215423, 0.4366057901469171, 0.23612863263579978, 0.18793564233873922, 0.23286843172673416, 0.18866013159243544, 0.33587925631845267, 0.2275424112819824, 0.17955938836068383, 0.2793552118665281, 0.11503105825049087, 0.1663157955403294, 0.18812355373966047, 0.30886895387185626]
# avg output_content_ssim score: 0.23530768297173096
# output_style_ssim: [0.03738481486703778, 0.07290213321647876, 0.14762056768575949, 0.060418510418792926, 0.02869098302529325, 0.040460124207419124, 0.07292159962365986, 0.18653620738845772, 0.07442427466866734, 0.029406542934913845, 0.031456320721618476, 0.08131203581808973, 0.20235641438258112, 0.09173475385058656, 0.015590965035715264, 0.033562255335553196, 0.06981776845653094, 0.1873173626602919, 0.07004571805627405, 0.02618615590379072, 0.04221874524056034, 0.06779844350126606, 0.14793328791531157, 0.08126377039951624, 0.03940858279126742]
# avg output_style_ssim score: 0.07755073352421733

# %% [markdown]
# # NST

# %%
def ssim_score(imgp1, imgp2):
  img1 = cv2.imread(imgp1)
  img2 = cv2.imread(imgp2)
  gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
  gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

  # calculate the SSIM score
  score = ssim(gray1, gray2)
  return score

cd = "/content/image_files_metrics/content" # @param {type:"string"}
sd = "/content/image_files_metrics/style"# @param {type:"string"}
od = "/content/image_files_metrics/nst_256"# @param {type:"string"}
image_tuples = get_image_tuples(cd = cd , sd = sd , od = od )
print(image_tuples)

print("Total Inferences: {}".format(len(image_tuples)))
count = 0
ssim_score_array_oc = []
ssim_score_array_os = []
for t in image_tuples:
  cp, sp, op = t[0],t[1],t[2]
  # print(cp)
  # print(sp)
  # print(op)
  count += 1
  score_oc = ssim_score(op, cp)
  score_os = ssim_score(op, sp)
  # print("Processing Inference :{}/{} Image : {} , score : {}".format(count, len(image_tuples), op , score))
  ssim_score_array_oc.append(score_oc)
  ssim_score_array_os.append(score_os)

print("output_content_ssim: {}".format(ssim_score_array_oc))
print("avg output_content_ssim score: {}".format(np.mean(np.array(ssim_score_array_oc))) )
print("output_style_ssim: {}".format(ssim_score_array_os))
print("avg output_style_ssim score: {}".format(np.mean(np.array(ssim_score_array_os))) )
# Out:
# [('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/nst_256/content_building_style_1.jpg'), ('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/nst_256/content_building_style_2.jpg'), ('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/nst_256/content_building_style_3.jpg'), ('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/nst_256/content_building_style_4.jpg'), ('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/5.jpg', '/content/image_files_metrics/nst_256/content_building_style_5.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/nst_256/content_car_style_1.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/nst_256/content_car_style_2.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/nst_256/content_car_style_3.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/nst_256/content_car_style_4.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/5.jpg', '/content/image_files_metrics/nst_256/content_car_style_5.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/nst_256/content_dog_style_1.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/nst_256/content_dog_style_2.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/nst_256/content_dog_style_3.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/nst_256/content_dog_style_4.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/5.jpg', '/content/image_files_metrics/nst_256/content_dog_style_5.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/nst_256/content_painting_style_1.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/nst_256/content_painting_style_2.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/nst_256/content_painting_style_3.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/nst_256/content_painting_style_4.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/5.jpg', '/content/image_files_metrics/nst_256/content_painting_style_5.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/nst_256/content_person_style_1.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/nst_256/content_person_style_2.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/nst_256/content_person_style_3.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/nst_256/content_person_style_4.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/s ...
# Total Inferences: 25
# output_content_ssim: [0.3177842125865725, 0.279129082200015, 0.32327228456916396, 0.3375305588116574, 0.33138082018253623, 0.23011905214640993, 0.2574136059551492, 0.3871838866389704, 0.24771497143034926, 0.19364449692830005, 0.24747960912915726, 0.33986814128466836, 0.5784924384018593, 0.33148654758103147, 0.2257209779826858, 0.27611495988910484, 0.27151716772595885, 0.43101192064914434, 0.2802656331285269, 0.2216442893237957, 0.33103196684524866, 0.17655712531918527, 0.2488778131808279, 0.23373541840400675, 0.3492197949950532]
# avg output_content_ssim score: 0.29792787101157514
# output_style_ssim: [0.045217579092355215, 0.09097198999716614, 0.20150289775716704, 0.09616158585975179, 0.031998515756250914, 0.0443118850079437, 0.09613968745798156, 0.24351912740992973, 0.10192107043766166, 0.03567091068566529, 0.038793453534168416, 0.10687357860678147, 0.26005189985867977, 0.13673521161345673, 0.023993086239984484, 0.03798881470753289, 0.08620411690363258, 0.23110495611645065, 0.10033196199385924, 0.03008674500996393, 0.04590047816646822, 0.08036124956016866, 0.18160578315681836, 0.1070058686693328, 0.04507591957628385]
# avg output_style_ssim score: 0.09998113492701821
