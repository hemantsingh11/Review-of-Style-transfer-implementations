# %% [markdown]
# # Import Libraries

# %%
import os 
import numpy as np 
from skimage.metrics import structural_similarity as ssim
import cv2
import subprocess

# %% [markdown]
# # Get Image Tuples

# %%
def get_image_tuples(cd, sd, od ):

  content_dir = cd
  style_dir = sd
  out_dir = od

  # to get image tuples of only one style
  only_one_style_all_images = False
  style_image_name = ["1.jpg"]

  image_tuples = []

  if only_one_style_all_images:
    for s in style_image_name:
      if ".DS_Store" in s:
        continue
      sn = s.split(".")[0]
      for c in os.listdir(content_dir):
        if ".DS_Store" in c:
          continue
        cn = c.split(".")[0]
        fsp = os.path.join(style_dir,s)
        fcp = os.path.join(content_dir,c)
        
        on = "content_"+str(cn)+"_style_"+str(sn)+".jpg"
        op = os.path.join(out_dir,on)
        image_tuples.append((fcp,fsp,op))

  else:
    for s in os.listdir(style_dir):
      if ".DS_Store" in s:
        continue
      sn = s.split(".")[0]
      for c in os.listdir(content_dir):
        if ".DS_Store" in c:
          continue
        cn = c.split(".")[0]
        fsp = os.path.join(style_dir,s)
        fcp = os.path.join(content_dir,c)
        
        on = "content_"+str(cn)+"_style_"+str(sn)+".jpg"
        op = os.path.join(out_dir,on)
        image_tuples.append((fcp,fsp,op))

      # also make output directory if missing 
      # subprocess.run("mkdir "+str(out_dir), shell = True)

  return image_tuples

# %% [markdown]
# # Get your files Unzipped

# %%
# !unzip /content/image_files_metrics.zip
# Out:
# Archive:  /content/image_files_metrics.zip
#    creating: image_files_metrics/
#   inflating: __MACOSX/._image_files_metrics
#   inflating: image_files_metrics/.DS_Store
#   inflating: __MACOSX/image_files_metrics/._.DS_Store
#    creating: image_files_metrics/artistic_384/
#   inflating: __MACOSX/image_files_metrics/._artistic_384
#    creating: image_files_metrics/fast_style_256/
#   inflating: __MACOSX/image_files_metrics/._fast_style_256
#    creating: image_files_metrics/content/
#    creating: image_files_metrics/style/
#   inflating: image_files_metrics/artistic_384/content_car_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_car_style_1.jpg
#   inflating: image_files_metrics/artistic_384/content_building_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_building_style_3.jpg
#   inflating: image_files_metrics/artistic_384/content_building_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_building_style_2.jpg
#   inflating: image_files_metrics/artistic_384/content_car_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_car_style_2.jpg
#   inflating: image_files_metrics/artistic_384/content_building_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_building_style_1.jpg
#   inflating: image_files_metrics/artistic_384/content_car_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_car_style_3.jpg
#   inflating: image_files_metrics/artistic_384/content_building_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_building_style_5.jpg
#   inflating: image_files_metrics/artistic_384/content_building_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_building_style_4.jpg
#   inflating: image_files_metrics/artistic_384/content_car_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_car_style_4.jpg
#   inflating: image_files_metrics/artistic_384/content_car_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_car_style_5.jpg
#   inflating: image_files_metrics/artistic_384/content_person_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_person_style_3.jpg
#   inflating: image_files_metrics/artistic_384/content_person_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_person_style_2.jpg
#   inflating: image_files_metrics/artistic_384/content_person_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_person_style_1.jpg
#   inflating: image_files_metrics/artistic_384/content_person_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_person_style_5.jpg
#   inflating: image_files_metrics/artistic_384/content_person_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_person_style_4.jpg
#   inflating: image_files_metrics/artistic_384/content_painting_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_painting_style_5.jpg
#   inflating: image_files_metrics/artistic_384/content_painting_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_painting_style_4.jpg
#   inflating: image_files_metrics/artistic_384/content_painting_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_painting_style_1.jpg
#   inflating: image_files_metrics/artistic_384/content_painting_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_painting_style_3.jpg
#   inflating: image_files_metrics/artistic_384/content_painting_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_painting_style_2.jpg
#   inflating: image_files_metrics/artistic_384/content_dog_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_dog_style_5.jpg
#   inflating: image_files_metrics/artistic_384/content_dog_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_dog_style_4.jpg
#   inflating: image_files_metrics/artistic_384/content_dog_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_dog_style_1.jpg
#   inflating: image_files_metrics/artistic_384/content_dog_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_dog_style_3.jpg
#   inflating: image_files_metrics/artistic_384/content_dog_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/artistic_384/._content_dog_style_2.jpg
#   inflating: image_files_metrics/fast_style_256/content_car_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_car_style_1.jpg
#   inflating: image_files_metrics/fast_style_256/content_building_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_building_style_3.jpg
#   inflating: image_files_metrics/fast_style_256/content_building_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_building_style_2.jpg
#   inflating: image_files_metrics/fast_style_256/content_car_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_car_style_2.jpg
#   inflating: image_files_metrics/fast_style_256/content_building_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_building_style_1.jpg
#   inflating: image_files_metrics/fast_style_256/content_car_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_car_style_3.jpg
#   inflating: image_files_metrics/fast_style_256/content_building_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_building_style_5.jpg
#   inflating: image_files_metrics/fast_style_256/content_building_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_building_style_4.jpg
#   inflating: image_files_metrics/fast_style_256/content_car_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_car_style_4.jpg
#   inflating: image_files_metrics/fast_style_256/content_car_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_car_style_5.jpg
#   inflating: image_files_metrics/fast_style_256/content_person_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_person_style_3.jpg
#   inflating: image_files_metrics/fast_style_256/content_person_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_person_style_2.jpg
#   inflating: image_files_metrics/fast_style_256/content_person_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_person_style_1.jpg
#   inflating: image_files_metrics/fast_style_256/content_person_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_person_style_5.jpg
#   inflating: image_files_metrics/fast_style_256/content_person_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_person_style_4.jpg
#   inflating: image_files_metrics/fast_style_256/content_painting_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_painting_style_5.jpg
#   inflating: image_files_metrics/fast_style_256/content_painting_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_painting_style_4.jpg
#   inflating: image_files_metrics/fast_style_256/content_painting_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_painting_style_1.jpg
#   inflating: image_files_metrics/fast_style_256/content_painting_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_painting_style_3.jpg
#   inflating: image_files_metrics/fast_style_256/content_painting_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_painting_style_2.jpg
#   inflating: image_files_metrics/fast_style_256/content_dog_style_5.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_dog_style_5.jpg
#   inflating: image_files_metrics/fast_style_256/content_dog_style_4.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_dog_style_4.jpg
#   inflating: image_files_metrics/fast_style_256/content_dog_style_1.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_dog_style_1.jpg
#   inflating: image_files_metrics/fast_style_256/content_dog_style_3.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_dog_style_3.jpg
#   inflating: image_files_metrics/fast_style_256/content_dog_style_2.jpg
#   inflating: __MACOSX/image_files_metrics/fast_style_256/._content_dog_style_2.jpg
#   inflating: image_files_metrics/content/dog.jpg
#   inflating: __MACOSX/image_files_metrics/content/._dog.jpg
#   inflating: image_files_metrics/content/person.jpg
#   inflating: __MACOSX/image_files_metrics/content/._person.jpg
#   inflating: image_files_metrics/content/painting.jpg
#   inflating: __MACOSX/image_files_metrics/content/._painting.jpg
#   inflating: image_files_metrics/content/building.jpg
#   inflating: __MACOSX/image_files_metrics/content/._building.jpg
#   inflating: image_files_metrics/content/car.jpg
#   inflating: __MACOSX/image_files_metrics/content/._car.jpg
#   inflating: image_files_metrics/style/4.jpg
#   inflating: __MACOSX/image_files_metrics/style/._4.jpg
#   inflating: image_files_metrics/style/5.jpg
#   inflating: __MACOSX/image_files_metrics/style/._5.jpg
#   inflating: image_files_metrics/style/2.jpg
#   inflating: __MACOSX/image_files_metrics/style/._2.jpg
#   inflating: image_files_metrics/style/3.jpg
#   inflating: __MACOSX/image_files_metrics/style/._3.jpg
#   inflating: image_files_metrics/style/1.jpg
#   inflating: __MACOSX/image_files_metrics/style/._1.jpg

# %% [markdown]
# # SSIM Batch Processing

# %%
def ssim_score(cp, sp, op):
  img1 = cv2.imread(cp)
  img2 = cv2.imread(op)
  gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
  gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

  # calculate the SSIM score
  score = ssim(gray1, gray2)
  return score

# cp = "/content/building.jpg" # @param {type:"string"}
# sp = "/content/1.jpg"# @param {type:"string"}
# op = "/content/content_building_style_1.jpg"# @param {type:"string"}
# score = ssim_score(cp = cp, sp = sp, op = op)
# print("ssim score : {}".format(score))

# content_dir
# style_dir
# out_dir

cd = "/content/image_files_metrics/content" # @param {type:"string"}
sd = "/content/image_files_metrics/style"# @param {type:"string"}
od = "/content/image_files_metrics/fast_style_256"# @param {type:"string"}
image_tuples = get_image_tuples(cd = cd , sd = sd , od = od )
print(image_tuples)

print("Total Inferences: {}".format(len(image_tuples)))
count = 0
ssim_score_array = []
for t in image_tuples:
  cp, sp, op = t[0],t[1],t[2]
  # print(cp)
  # print(sp)
  # print(op)
  count += 1
  score = ssim_score(cp = cp, sp = sp, op = op)
  print("Processing Inference :{}/{} Image : {} , score : {}".format(count, len(image_tuples), op , score))
  ssim_score_array.append(score)

print(ssim_score_array)
print("avg ssim score: {}".format(np.mean(np.array(ssim_score_array))) )
# Out:
# [('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/fast_style_256/content_car_style_2.jpg'), ('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/fast_style_256/content_building_style_2.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/fast_style_256/content_person_style_2.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/fast_style_256/content_dog_style_2.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/2.jpg', '/content/image_files_metrics/fast_style_256/content_painting_style_2.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/fast_style_256/content_car_style_3.jpg'), ('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/fast_style_256/content_building_style_3.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/fast_style_256/content_person_style_3.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/fast_style_256/content_dog_style_3.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/3.jpg', '/content/image_files_metrics/fast_style_256/content_painting_style_3.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/fast_style_256/content_car_style_1.jpg'), ('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/fast_style_256/content_building_style_1.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/fast_style_256/content_person_style_1.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/fast_style_256/content_dog_style_1.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/1.jpg', '/content/image_files_metrics/fast_style_256/content_painting_style_1.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/fast_style_256/content_car_style_4.jpg'), ('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/fast_style_256/content_building_style_4.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/fast_style_256/content_person_style_4.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/fast_style_256/content_dog_style_4.jpg'), ('/content/image_files_metrics/content/painting.jpg', '/content/image_files_metrics/style/4.jpg', '/content/image_files_metrics/fast_style_256/content_painting_style_4.jpg'), ('/content/image_files_metrics/content/car.jpg', '/content/image_files_metrics/style/5.jpg', '/content/image_files_metrics/fast_style_256/content_car_style_5.jpg'), ('/content/image_files_metrics/content/building.jpg', '/content/image_files_metrics/style/5.jpg', '/content/image_files_metrics/fast_style_256/content_building_style_5.jpg'), ('/content/image_files_metrics/content/person.jpg', '/content/image_files_metrics/style/5.jpg', '/content/image_files_metrics/fast_style_256/content_person_style_5.jpg'), ('/content/image_files_metrics/content/dog.jpg', '/content/image_files_metrics/style ...
# Total Inferences: 25
# Processing Inference :1/25 Image : /content/image_files_metrics/fast_style_256/content_car_style_2.jpg , score : 0.4785866666015451
# Processing Inference :2/25 Image : /content/image_files_metrics/fast_style_256/content_building_style_2.jpg , score : 0.559311351507912
# Processing Inference :3/25 Image : /content/image_files_metrics/fast_style_256/content_person_style_2.jpg , score : 0.510123556670477
# Processing Inference :4/25 Image : /content/image_files_metrics/fast_style_256/content_dog_style_2.jpg , score : 0.6683812115713347
# Processing Inference :5/25 Image : /content/image_files_metrics/fast_style_256/content_painting_style_2.jpg , score : 0.4512944233334624
# Processing Inference :6/25 Image : /content/image_files_metrics/fast_style_256/content_car_style_3.jpg , score : 0.5401453801110007
# Processing Inference :7/25 Image : /content/image_files_metrics/fast_style_256/content_building_style_3.jpg , score : 0.4677214925046697
# Processing Inference :8/25 Image : /content/image_files_metrics/fast_style_256/content_person_style_3.jpg , score : 0.4307791047487009
# Processing Inference :9/25 Image : /content/image_files_metrics/fast_style_256/content_dog_style_3.jpg , score : 0.7376074520951543
# Processing Inference :10/25 Image : /content/image_files_metrics/fast_style_256/content_painting_style_3.jpg , score : 0.5224600303991023
# Processing Inference :11/25 Image : /content/image_files_metrics/fast_style_256/content_car_style_1.jpg , score : 0.33868890088106257
# Processing Inference :12/25 Image : /content/image_files_metrics/fast_style_256/content_building_style_1.jpg , score : 0.41826128411145413
# Processing Inference :13/25 Image : /content/image_files_metrics/fast_style_256/content_person_style_1.jpg , score : 0.48703860455526243
# Processing Inference :14/25 Image : /content/image_files_metrics/fast_style_256/content_dog_style_1.jpg , score : 0.4671822533451772
# Processing Inference :15/25 Image : /content/image_files_metrics/fast_style_256/content_painting_style_1.jpg , score : 0.40415697379654203
# Processing Inference :16/25 Image : /content/image_files_metrics/fast_style_256/content_car_style_4.jpg , score : 0.2913674239077182
# Processing Inference :17/25 Image : /content/image_files_metrics/fast_style_256/content_building_style_4.jpg , score : 0.15856935141747333
# Processing Inference :18/25 Image : /content/image_files_metrics/fast_style_256/content_person_style_4.jpg , score : 0.1828242155795048
# Processing Inference :19/25 Image : /content/image_files_metrics/fast_style_256/content_dog_style_4.jpg , score : 0.3400800697259076
# Processing Inference :20/25 Image : /content/image_files_metrics/fast_style_256/content_painting_style_4.jpg , score : 0.30438855181166613
# Processing Inference :21/25 Image : /content/image_files_metrics/fast_style_256/content_car_style_5.jpg , score : 0.3072646005401312
# Processing Inference :22/25 Image : /content/image_files_metrics/fast_style_256/content_building_style_5.jpg , score : 0.48168520762593786
# Processing Inference :23/25 Image : /content/image_files_metrics/fast_style_256/content_person_style_5.jpg , score : 0.45978444599902024
# Processing Inference :24/25 Image : /content/image_files_metrics/fast_style_256/content_dog_style_5.jpg , score : 0.42511197301227316
# Processing Inference :25/25 Image : /content/image_files_metrics/fast_style_256/content_painting_style_5.jpg , score : 0.33647175824000347
# [0.4785866666015451, 0.559311351507912, 0.510123556670477, 0.6683812115713347, 0.4512944233334624, 0.5401453801110007, 0.4677214925046697, 0.4307791047487009, 0.7376074520951543, 0.5224600303991023, 0.33868890088106257, 0.41826128411145413, 0.48703860455526243, 0.4671822533451772, 0.40415697379654203, 0.2913674239077182, 0.15856935141747333, 0.1828242155795048, 0.3400800697259076, 0.30438855181166613, 0.3072646005401312, 0.48168520762593786, 0.45978444599902024, 0.42511197301227316, 0.33647175824000347]
# avg ssim score: 0.4307714513636997
